# %%
# !nvidia-smi -L

# %% [markdown]
# The collab runs a modified version Stable diffusion by hiki
#
# **Colab was created by user: daswer123**
#
# https://github.com/daswer123/stable-diffusion-colab
#
# **If you liked the colab, give it a star :)**

# %% [markdown]
# **There is a bug which causes the images in gradio to stop loading after 60 seconds.**
#
# Pictures are saved in any case and you can see them in the outputs folder
#
# To fix this, simply reload the page gradio, but the settings will be lost
#
# You can also use Localtunnel then this problem will not happen

# %% [markdown]
# ## Setup 1 stage
# Clone git repo and setup miniconda
#
# After runtime is executed, it will restart

# %% [markdown]
# **Choose only one!**

# %% [markdown]
# ###Main version

# %%
# !git clone https://github.com/sd-webui/stable-diffusion-webui

# %%
# %cd /content/stable-diffusion-webui
# !pip install -e .

# %%
# !pip install condacolab
import condacolab
condacolab.install_miniconda()

# %% [markdown]
# ###DEV version
# https://github.com/sd-webui/stable-diffusion-webui/tree/dev

# %%
# !git clone https://github.com/sd-webui/stable-diffusion-webui -b dev
# Out:
# Cloning into 'stable-diffusion-webui'...
# remote: Enumerating objects: 3860, done.
# remote: Counting objects: 100% (411/411), done.
# remote: Compressing objects: 100% (198/198), done.
# remote: Total 3860 (delta 229), reused 364 (delta 211), pack-reused 3449
# Receiving objects: 100% (3860/3860), 30.33 MiB | 16.51 MiB/s, done.
# Resolving deltas: 100% (2253/2253), done.

# %%
# %cd /content/stable-diffusion-webui
# !pip install -e .
# Out:
# /content/stable-diffusion-webui
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Obtaining file:///content/stable-diffusion-webui
# ...
#   Running setup.py develop for sd-webui
# ...

# %%
# !pip install condacolab
import condacolab
condacolab.install_miniconda()
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# ⏬ Downloading https://repo.anaconda.com/miniconda/Miniconda3-py37_4.12.0-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:20
# 🔁 Restarting kernel...

# %% [markdown]
# ## Setup 2 stage
# ### Setup envoroment, Gfpgan and Real-ESRGAN
# Setup takes about 5-6 minutes

# %%
# %cd /content
# !conda env update -n base -f stable-diffusion-webui/environment.yaml
# Out:
# /content
# done
# | WARNING conda.core.solve:_add_specs(649): pinned spec python=3.7 conflicts with explicit specs.  Overriding pinned spec.
# WARNING conda.core.solve:_add_specs(649): pinned spec cudatoolkit=11.1 conflicts with explicit specs.  Overriding pinned spec.
# done
#
# ...
# scipy-1.7.3          | 16.6 MB   | : 100% 1.0/1 [00:00<00:00,  1.77it/s]
# loguru-0.5.3         | 84 KB     | : 100% 1.0/1 [00:00<00:00,  2.77it/s]
# c-ares-1.18.1        | 114 KB    | : 100% 1.0/1 [00:00<00:00, 18.37it/s]
# typing_extensions-4. | 42 KB     | : 100% 1.0/1 [00:00<00:00, 21.82it/s]
# pytorch-mutex-1.0    | 3 KB      | : 100% 1.0/1 [00:00<00:00, 18.01it/s]
# libaec-1.0.4         | 32 KB     | : 100% 1.0/1 [00:00<00:00, 20.04it/s]
# libpng-1.6.37        | 278 KB    | : 100% 1.0/1 [00:00<00:00, 18.43it/s]
# libtiff-4.2.0        | 502 KB    | : 100% 1.0/1 [00:00<00:00, 17.78it/s]
# python-3.8.5         | 49.3 MB   | : 100% 1.0/1 [00:00<00:00,  1.02it/s]
# ...

# %%
# %cd /content/stable-diffusion-webui/src/gfpgan/
# !pip install basicsr facexlib yapf lmdb opencv-python pyyaml tb-nightly --no-deps
# !python setup.py develop
# !pip install realesrgan
# !wget https://github.com/TencentARC/GFPGAN/releases/download/v1.3.0/GFPGANv1.3.pth -P experiments/pretrained_models
# Out:
# /content/stable-diffusion-webui/src/gfpgan
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# /usr/local/lib/python3.8/site-packages/setuptools/installer.py:27: SetuptoolsDeprecationWarning: setuptools.installer is deprecated. Requirements should be satisfied by a PEP 517 installer.
#   warnings.warn(
# running develop
# /usr/local/lib/python3.8/site-packages/setuptools/command/easy_install.py:156: EasyInstallDeprecationWarning: easy_install command is deprecated. Use build and pip and other standards-based tools.
#   warnings.warn(
# /usr/local/lib/python3.8/site-packages/setuptools/command/install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#   warnings.warn(
# running egg_info
# writing gfpgan.egg-info/PKG-INFO
# writing dependency_links to gfpgan.egg-info/dependency_links.txt
# writing requirements to gfpgan.egg-info/requires.txt
# ...

# %%
# %cd /content/stable-diffusion-webui/src/realesrgan/
# !wget https://github.com/xinntao/Real-ESRGAN/releases/download/v0.1.0/RealESRGAN_x4plus.pth -P experiments/pretrained_models
# !wget https://github.com/xinntao/Real-ESRGAN/releases/download/v0.2.2.4/RealESRGAN_x4plus_anime_6B.pth -P experiments/pretrained_models
# Out:
# [Errno 2] No such file or directory: '/content/stable-diffusion-webui/src/realesrgan/'
# /content/stable-diffusion-webui/src/gfpgan
# --2022-10-02 18:17:34--  https://github.com/xinntao/Real-ESRGAN/releases/download/v0.1.0/RealESRGAN_x4plus.pth
# Resolving github.com (github.com)... 20.205.243.166
# Connecting to github.com (github.com)|20.205.243.166|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# !wget https://github.com/matomo-org/travis-scripts/blob/master/fonts/Arial.ttf?raw=true -O /content/stable-diffusion-webui/arial.ttf
# Out:
# --2022-10-02 18:17:35--  https://github.com/matomo-org/travis-scripts/blob/master/fonts/Arial.ttf?raw=true
# Resolving github.com (github.com)... 20.205.243.166
# Connecting to github.com (github.com)|20.205.243.166|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/matomo-org/travis-scripts/raw/master/fonts/Arial.ttf [following]
# --2022-10-02 18:17:36--  https://github.com/matomo-org/travis-scripts/raw/master/fonts/Arial.ttf
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/matomo-org/travis-scripts/master/fonts/Arial.ttf [following]
# --2022-10-02 18:17:36--  https://raw.githubusercontent.com/matomo-org/travis-scripts/master/fonts/Arial.ttf
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# ...

# %%
# %cd /content/stable-diffusion-webui/src
# !git clone https://github.com/devilismyfriend/latent-diffusion
# %cd /content/stable-diffusion-webui/src/latent-diffusion
# !mkdir experiments
# %cd experiments/
# !mkdir pretrained_models
# !wget "https://heibox.uni-heidelberg.de/f/31a76b13ea27482981b4/?dl=1" -o /content/stable-diffusion-webui/src/latent-diffusion/experiments/pretrained_models/project.yaml
# !wget "https://heibox.uni-heidelberg.de/f/578df07c8fc04ffbadf3/?dl=1" -o /content/stable-diffusion-webui/src/latent-diffusion/experiments/pretrained_models/model.ckpt
# Out:
# /content/stable-diffusion-webui/src
# fatal: destination path 'latent-diffusion' already exists and is not an empty directory.
# /content/stable-diffusion-webui/src/latent-diffusion
# /content/stable-diffusion-webui/src/latent-diffusion/experiments

# %%
# %cd /content/stable-diffusion-webui/scripts/
def replace_line(file_name, line_num, text):
    lines = open(file_name, 'r').readlines()
    lines[line_num] = text
    out = open(file_name, 'w')
    out.writelines(lines)
    out.close()

def replace_line_in_file(file_name, line_to_search, text_to_replace):
    with open(file_name, 'r') as file:
        # read a list of lines into data
        data = file.readlines()

    for line in data:
        # if the line contains the string we're looking for,
        # write the line to the output file
        if line_to_search in line:
            replace_line(file_name, data.index(line), text_to_replace)

replace_line_in_file('webui.py', 'pl_sd = torch.load(ckpt, map_location="cpu")', '    pl_sd = torch.load(ckpt, map_location="cuda:0")\n')
replace_line_in_file('webui.py', 'pl_sd = torch.load(ckpt, map_location="cpu")', '    pl_sd = torch.load(ckpt, map_location="cuda:0")\n')

# %% [markdown]
# ## Connect google drive and transfer model or download it
# Choose only 1 option

# %% [markdown]
# ### Gdrive
# **The weights must be in the google drive root folder**

# %% [markdown]
# You can create a shortcut to your google drive in main folder
# 1.4 version
# https://drive.google.com/file/d/1wHFgl0ivCmIZv88hVZXkb8oy9qCuaBGA/view?usp=sharing
#
# waifu-diffusion anime model
#
# https://drive.google.com/file/d/1XeoFCILTcc9kn_5uS-G0uqWS5XVANpha/edit

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
# %cd /content/stable-diffusion-webui
# !cp '/gdrive/MyDrive/SD_models/model-epoch06-full.ckpt' models/ldm/stable-diffusion-v1/model.ckpt
# Out:
# /content/stable-diffusion-webui

# %% [markdown]
# ### Download model ( Long wait )
# The long way, you need to download the model from the server

# %%
# %cd /content/stable-diffusion-webui/
# !wget "https://drive.yerf.org/wl/?id=EBfTrmcCCUAGaQBXVIj5lJmEhjoP1tgl&mode=grid&download=1" -O /content/stable-diffusion-colab/models/ldm/stable-diffusion-v1/model.ckpt

# %% [markdown]
# Waifu-Diffusion anime model

# %%
# %cd /content/stable-diffusion-webui/
# !wget "http://wd.links.sd:8880/wd-v1-2-full-ema.ckpt" -O /content/stable-diffusion-colab/models/ldm/stable-diffusion-v1/model.ckpt

# %% [markdown]
# # Launch Webui

# %% [markdown]
# ## Gradio host

# %%
# %cd /content/stable-diffusion-colab/ 
# !python3 scripts/webui.py --share

# %% [markdown]
# ## LocalTunnel
# ### Install tunnel to colab localhost
# To avoid the image output bug you can use the localtunnel

# %%
# %cd /content/stable-diffusion-webui
# !npm install -g localtunnel
# !nohup lt -p 7860 > lt.log 2>&1 &
# Out:
# /content/stable-diffusion-webui
# /tools/node/bin/lt -> /tools/node/lib/node_modules/localtunnel/bin/lt.js
# + localtunnel@2.0.2
# added 22 packages from 22 contributors in 2.048s

# %% [markdown]
# After you get the link localtunnel , run the next block and wait until it loads, then follow the link localtunnel

# %%
with open('/content/stable-diffusion-webui/lt.log', 'r') as testwritefile:
    print(testwritefile.read())
# %cd /content/stable-diffusion-webui/ 
# !python3 scripts/webui.py

# %% [markdown]
# If you want to restart the server, run the code

# %%
import os
os.kill(os.getpid(), 9)

# %% [markdown]
# # EXTRA

# %% [markdown]
# ## Another variant by AUTOMATIC1111
# https://colab.research.google.com/drive/1zN99ZouzlYObQaPfzwbgwJr6ZqcpYK5-?usp=sharing
